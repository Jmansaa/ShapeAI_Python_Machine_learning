# %%
 
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# Now we will load the data that we will be using to train our model

# %%
from sklearn.databsets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-3abc75ee38ac> in <module>()
# ----> 1 from sklearn.databsets import load_boston
#
# ModuleNotFoundError: No module named 'sklearn.databsets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df=load_boston()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-70cf8c417a25> in <module>()
# ----> 1 df=load_boston()
#
# NameError: name 'load_boston' is not defined

# %%
df.keys()#Returns all the keys of the dataset dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-100a6124d29e> in <module>()
# ----> 1 df.keys()#Returns all the keys of the dataset dictionary
#
# NameError: name 'df' is not defined

# %%
Print (df.data)#Info about the dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3d1bacdcbb35> in <module>()
# ----> 1 Print (df.data)#Info about the dataset
#
# NameError: name 'Print' is not defined

# %%
boston=Pd.Dataframe(df.data, columns=df.feature_names)
boston.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1ad83f03fd85> in <module>()
# ----> 1 boston=Pd.Dataframe(df.data, columns=df.feature_names)
#       2 boston.head(10)
#
# NameError: name 'Pd' is not defined

# %% [markdown]
# Adding a new column of target values to the data frame

# %%
boston['MEDV']=df.target
boston.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5b888f027ef9> in <module>()
# ----> 1 boston['MEDV']=df.target
#       2 boston.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Check if the dataset contains any null value or not

# %%
boston.is null()
boston.is null().sum()
# Out:
#   File "<ipython-input-9-a59f3fe7d72b>", line 1
#     boston.is null()
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# We never train the model on all the data that we have ,we always make sure to atleast have a test dataset, which is different from the training dataset

# %%
from sklearn.model_selection import train_test_split
X=boston.drop('MEDV',axis=1)
Y=boston ['MEDV']
X_train,X_test,Y_test=train_test_Split(X,Y,test_size=0.15,random_state=5)
Print (X_train.shape)
Print (X_test.shape)
Print (Y_train.shape)
Print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9d8592c0e255> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X=boston.drop('MEDV',axis=1)
#       3 Y=boston ['MEDV']
#       4 X_train,X_test,Y_test=train_test_Split(X,Y,test_size=0.15,random_state=5)
#       5 Print (X_train.shape)
#
# NameError: name 'boston' is not defined

# %% [markdown]
# Now lets import the linear regression model from sklearn and train it on the training dataset

# %%
from Sklearn.linear_model import linearRegression
from Sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-cd3103fa530d> in <module>()
# ----> 1 from Sklearn.linear_model import linearRegression
#       2 from Sklearn.metrics import mean_squared_error
#
# ModuleNotFoundError: No module named 'Sklearn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ##Fitting model on tge training dataset

# %%
Lin_model=linearRegression ()
Lin_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0bc4536d28f4> in <module>()
# ----> 1 Lin_model=linearRegression ()
#       2 Lin_model.fit(x_train,y_train)
#
# NameError: name 'linearRegression' is not defined

# %%
y_train_predict=lin_model.predict(X_train)
rmse=(np.sqrt(mean_squared_error(Y_train,y_train_predict))
Print ("The model performance for training set")
Print ("RMSE IS {}". format (rmse))
Print ("\n")
# Out:
#   File "<ipython-input-13-5e966744f344>", line 3
#     Print ("The model performance for training set")
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # on testing set

# %%
y_test_predict=lin_model.predict(X_test)
rmse=(np.sqrt(mean_squared_error(Y_test,y_test_predict))
Print ("The model performance for testing set")
Print ("RMSE is {}". format (rmse))
# Out:
#   File "<ipython-input-14-6232a9eff2ce>", line 3
#     Print ("The model performance for testing set")
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #MATPLOTLIB IS A LIBRARY TO PLOT THE CURVES
# #PART OF DATA VISUALIZATION
# #DO NOT NEED TO CODE

# %%
import matplotib.pyplot as Plt
Plt.figure(figsize=(5,5))
Plt.scatter(Y_test,y_test_predict)
Plt.plot([min(y_test_predict),max(y_test_predict)],
[min(y_test_predict),max(y_test_predict
Plt.Xlabel('Actual')
Plt.Ylabel('predicted')
# Out:
#   File "<ipython-input-15-6227b9503b3a>", line 6
#     Plt.Xlabel('Actual')
#       ^
# SyntaxError: invalid syntax
